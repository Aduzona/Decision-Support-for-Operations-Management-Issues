# %%
import numpy as np
import pandas as pd
import math

df= pd.read_excel(r'C:\Users\aduzo\Desktop\Scientific Project R\Scientific Project Main\Decision-Support-for-Operations-Management-Issues\product_data.xlsx') 

print(df)
period_mat= np.zeros(shape=(3,262))
# Out:
# box ID material ID  demand per day  pieces/box  price  demand_per_year  \
# 0   3103147  7348808+73              30          18   2.58              437
# 1   3103147  7346592+72             360          64   1.99             1474
# 2   3104147  7455691+71              24          20   4.39              315
# 3   3104147  7455692+71              24          20   4.39              315
# 4   3106410  7305865+77              30          14   3.15              562
# ..      ...         ...             ...         ...    ...              ...
# 57  6203061  7346813+73              60          30   2.45              524
# 58  6203061  7313474+73              30           8   2.82              983
# 59  6203061  7355005+72              30          36   1.67              219
# 60  6203062  7332421+76              30           5   3.45             1572
# 61  6203062  7332422+76              30           5   1.57             1572
#
#     box_cost  ordering_cost  b_sorting  b_not_sorting  eoq.min  eoq.max  \
# 0      46.44             50        198            297       97      540
# 1     127.36             50        198            297      108      599
# 2      87.80             45        396            297       57      333
# 3      87.80             45        396            297       57      333
# 4      44.10             60        594            396      124      631
# ..       ...            ...        ...            ...      ...      ...
# 57     73.50             50        198            297       84      470
# 58     22.56             50        198            297      209     1162
# 59     60.12             50        198            297       60      336
# 60     17.25             70        594            396      357     1692
# 61      7.85             70        594            396      529     2508
#
#     deman_per_day_boxes  cycle_time_in_days  Order_frequency_M  Lot_size_q  \
# 0              1.666667            9.895966                  4          17
# 1              5.625000            2.472524                  1          14
# 2              1.200000           14.860934                  6          18
# 3              1.200000           14.860934                  6          18
# 4              2.142857            7.423862                  3          16
# ..                  ...                 ...                ...         ...
# 57             2.000000            7.416313                  3          15
# 58             3.750000            4.946725                  2          19
# 59             0.833333           19.837223                  8          17
# 60             6.000000            2.472104                  1          15
# 61             6.000000            2.472104                  1          15
#
#     number_of_lanes
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 57                1
# 58                1
# 59                1
# 60                1
# 61                1
#
# [62 rows x 17 columns]

# %%
item= 2 #this is item 30 since counting starts from zero
item =item -1

rack_length=6000

b_not_sorting =df[['b_not_sorting']]
b_not_sorting =b_not_sorting.to_numpy()

l_start2 = df[['number_of_lanes']]
l_start2 =l_start2.to_numpy()
#type(l_start2)
dem = df[['deman_per_day_boxes']]
dem = dem.to_numpy()

quant= df[['Lot_size_q']]
quant = quant.to_numpy()

stock_level = (l_start2*rack_length)/b_not_sorting
stock_level[item]

#stock_level

period_mat= np.zeros(shape=(3,262))
period_mat.shape
m = df[['cycle_time_in_days']]
m = m.to_numpy()

# %%
t=0
for t in range(0,262):
    if item == 11:
        if t==0:
            period_mat[0,t]=dem[item]
            period_mat[2,t] = stock_level[item]

        else:
            period_mat[0,t]=dem[item]
            if  t % math.floor(m[item]) == 0 :
                period_mat[1,t] = stock_level[item] - (period_mat[2,t-1] + quant[item])

                #fill the capacity
                period_mat[2,t] = stock_level[item]
            else:
                period_mat[1,t] = 0
                period_mat[2,t] = period_mat[2,t-1]-dem[item]
    
    elif item == 29:
        if t==0:
            period_mat[0,t]=dem[item]
            period_mat[2,t] = stock_level[item]

        else:
            period_mat[0,t]=dem[item]
            if  t % math.floor(m[item]) == 0 :
                period_mat[1,t] = stock_level[item] - (period_mat[2,t-1] + quant[item])

                #fill the capacity
                period_mat[2,t] = stock_level[item]
            else:
                period_mat[1,t] = 0
                period_mat[2,t] = period_mat[2,t-1]-dem[item]


    else:

        if t==0:
            period_mat[0,t]=dem[item]
            period_mat[2,t] = stock_level[item]
        
        elif t==1:
            period_mat[0,t]=dem[item]
            period_mat[1,t]= 0
            period_mat[2,t] = stock_level[item] - quant[item]

        else:
            if  t % math.floor(m[item]) == 1 :
                period_mat[0,t]=dem[item]
            
                period_mat[1,t] = stock_level[item] - (period_mat[2,t-1] + quant[item])

                #fill the capacity
                period_mat[2,t] = stock_level[item]
            else:
                period_mat[1,t] = 0
                period_mat[2,t] = period_mat[2,t-1]-dem[item]


print(period_mat)
# Out:
# [[ 5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625      5.625      5.625
#    5.625      5.625      5.625      5.625    ]
#  [ 0.         0.         0.         5.625      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375      0.        -8.375
#    0.        -8.375      0.        -8.375    ]
#  [20.2020202  6.2020202  0.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202 14.5770202 20.2020202
#   14.5770202 20.2020202 14.5770202 20.2020202]]

# %%
period_mat[0,t]=dem[item]
pd.DataFrame(data= period_mat, index=["demand","quantity","Inventory Level"],columns=range(1,263))
# Out:
#                        1          2          3          4          5    \
# demand            1.666667   1.666667   1.666667   1.666667   1.666667
# quantity          0.000000  17.000000   0.000000   0.000000   0.000000
# Inventory Level  20.202020  20.202020  18.535354  16.868687  15.202020
#
#                        6          7          8         9         10   ...  \
# demand            1.666667   1.666667   1.666667  1.666667  1.666667  ...
# quantity          0.000000   0.000000   0.000000  0.000000  0.000000  ...
# Inventory Level  13.535354  11.868687  10.202020  8.535354  6.868687  ...
#
#                       253        254        255        256        257  \
# demand           1.666667   1.666667   1.666667   1.666667   1.666667
# quantity         0.000000  17.000000   0.000000   0.000000   0.000000
# Inventory Level  6.868687  20.202020  18.535354  16.868687  15.202020
#
#                        258        259        260       261       262
# demand            1.666667   1.666667   1.666667  1.666667  1.666667
# quantity          0.000000   0.000000   0.000000  0.000000  0.000000
# Inventory Level  13.535354  11.868687  10.202020  8.535354  6.868687
#
# [3 rows x 262 columns]

# %%
for i in range(1,6):
    print(i)
period_mat[1,262]
# Out:
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-102-6d41f649c3b0> in <module>
#       1 for i in range(1,6):
#       2     print(i)
# ----> 3 period_mat[1,262]
#
# IndexError: index 262 is out of bounds for axis 1 with size 262
